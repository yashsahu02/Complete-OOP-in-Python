# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## *Everything in Python is an object.*

# %% [markdown]
# ## OOP is just a different way of writing code.

# %% [markdown]
# ## Ojbect Oriented Programming Concepts -->
# #### - Object
# #### - Class
# #### - Inheritance
# #### - Encapsulation
# #### - Polymorphism
# #### - Abstraction

# %% [markdown]
# ### Class -->
# Class is a blueprint.

# %%
a = 2

# %%
type(a) ## so here a in integer is of class 'int'

# %% [markdown]
# In python datatype is a class and when we create a variable of that data type then that is a object of that class.

# %% [markdown]
# class has two main things -->
# - Data or Property
# - Functions or behavior

# %% [markdown]
# class ka naam should be in ***Pascal Case***

# %% [markdown]
# ### Object -->
# Object is an instance of the class.

# %% [markdown]
# Let's create a Class...

# %% [markdown]
# ### Function Vs Methods
# #### - Methods are basically functions that are written inside the class.
# #### - Methods are applied using . after any object. e.g. l.append(5) so, here append is here not a function is a method.

# %%
class Atm:
    ## Constructor -> It is a special method that is outomatically executed when the instance of the class is created.
    def __init__(self):
        self.pin = ""
        self.balance = 0

        self.menu()

    def menu(self):
        user_input = input("""Hello, how would you like to proceed? 
                              1. Enter 1 to create pin
                              2. Enter 2 to deposit
                              3. Enter 3 to withdraw
                              4. Enter 4 to check balance
                              5. Enter 5 to exit
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print("By by")

    def create_pin(self):
        p = input("Enter Your Pin")
        self.pin = p
        print("Pin Set Successfully..")
        
    def deposit(self):
        temp = input("Enter Your Pin:")
        if temp == self.pin:
            amount = int(input("Enter the amount:"))
            self.balance += amount
            print("Amout Deposited Successfully..")
        else:
            print("Invalid Pin")
            
    def withdraw(self):
        temp = input("Enter Your Pin:")
        if temp == self.pin:
            amount = int(input("Enter the amount:"))
            if amount<=self.balance:  
                self.balance -= amount
                print("Amout Withdrawed Successfully..")
            else:
                print("Insufficient funds..")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        temp = input("Enter Your Pin:")
        if temp == self.pin:
            print("Your balance is {}".format(self.balance))
            print("Balance Fetched Successfully..")
        else:
            print("Invalid Pin")

# %%
sbi = Atm()

# %%
sbi.deposit()

# %%
sbi.deposit()

# %%
sbi.check_balance()

# %%
sbi.withdraw()

# %%
sbi.withdraw()

# %%
sbi.withdraw()

# %%
sbi.check_balance()

# %% [markdown]
# ### Magic Methods -->

# %% [markdown]
# - There are some magic/special methods in python which starts and ends with __ like e.g. __ init __

# %% [markdown]
# - All the magic methods are predefined and are in fixed number.

# %% [markdown]
# ### Self -->
# If we check id(self) and id(object which we created) will we same it means self is the object with which we are working...

# %% [markdown]
# ### Why we need self in every method
# - Because the one method of class can not be accessed by the other one it can only be accessed by the object of that class so we need to pass self always.

# %% [markdown]
# ## Creating a fraction class to create a fraction data type

# %%
class Fraction():
    def __init__(self,n,d):
        self.num = n
        self.den = d

    def __str__(self):
        return "{}/{}".format(self.num,self.den)


    def __add__(self,other):
        temp_num = (self.num*other.den) + (other.num*self.den)
        temp_den = self.den*other.den
        return "{}/{}".format(temp_num,temp_den)
        
    def __sub__(self,other):
        temp_num = (self.num*other.den) - (other.num*self.den)
        temp_den = self.den*other.den
        return "{}/{}".format(temp_num,temp_den)
        
    def __mul__(self,other):
        temp_num = self.num * other.num
        temp_den = self.den*other.den
        return "{}/{}".format(temp_num,temp_den)
        
    def __truediv__(self,other):
        temp_num = self.num * other.den
        temp_den = self.den*other.num
        return "{}/{}".format(temp_num,temp_den)

# %%
x = Fraction(3,4)

# %%
y = Fraction(5,6)

# %%
type(x)

# %%
print(x)

# %%
print(y)

# %%
print(x+y)

# %%
print(x-y)

# %%
x-y

# %%
print(x*y)

# %%
print(x/y)

# %% [markdown]
# ## Instance Variable -->
# - Variable that are created inside constructor that are called instance varaibles and their value is different for every different objects.

# %% [markdown]
# ## Encapsulation

# %%
class Atm:
    ## Constructor -> It is a special method that is outomatically executed when the instance of the class is created.
    def __init__(self):
        self.__pin = ""
        self.__balance = 0

        ## we use double underscore __ before name of variable to make them private and can not be accessed 

        self.menu()

    def menu(self):
        user_input = input("""Hello, how would you like to proceed? 
                              1. Enter 1 to create pin
                              2. Enter 2 to deposit
                              3. Enter 3 to withdraw
                              4. Enter 4 to check balance
                              5. Enter 5 to exit
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print("By by")

    def create_pin(self):
        p = input("Enter Your Pin")
        self.__pin = p
        print("Pin Set Successfully..")
        
    def deposit(self):
        temp = input("Enter Your Pin:")
        if temp == self.pin:
            amount = int(input("Enter the amount:"))
            self.__balance += amount
            print("Amout Deposited Successfully..")
        else:
            print("Invalid Pin")
            
    def withdraw(self):
        temp = input("Enter Your Pin:")
        if temp == self.__pin:
            amount = int(input("Enter the amount:"))
            if amount<=self.__balance:  
                self.__balance -= amount
                print("Amout Withdrawed Successfully..")
            else:
                print("Insufficient funds..")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        temp = input("Enter Your Pin:")
        if temp == self.__pin:
            print("Your balance is {}".format(self.__balance))
            print("Balance Fetched Successfully..")
        else:
            print("Invalid Pin")

# %%
bob = Atm()

# %%
# bob.pin ## Here it will generate error 

## Its a good practice to hide our data members.

# %%
## Python do like __pin -> _Atm__pin

# %% [markdown]
# # *Nothing in Python is truly private*

# %%
## we can create method here to show pin which is like private

# %%
class Atm:
    ## Constructor -> It is a special method that is outomatically executed when the instance of the class is created.
    def __init__(self):
        self.__pin = ""
        self.__balance = 0

        ## we use double underscore __ before name of variable to make them private and can not be accessed 

        self.menu()

    def get_pin(self):
        return self.__pin

    def menu(self):
        user_input = input("""Hello, how would you like to proceed? 
                              1. Enter 1 to create pin
                              2. Enter 2 to deposit
                              3. Enter 3 to withdraw
                              4. Enter 4 to check balance
                              5. Enter 5 to exit
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print("By by")

    def create_pin(self):
        p = input("Enter Your Pin")
        self.__pin = p
        print("Pin Set Successfully..")
        
    def deposit(self):
        temp = input("Enter Your Pin:")
        if temp == self.pin:
            amount = int(input("Enter the amount:"))
            self.__balance += amount
            print("Amout Deposited Successfully..")
        else:
            print("Invalid Pin")
            
    def withdraw(self):
        temp = input("Enter Your Pin:")
        if temp == self.__pin:
            amount = int(input("Enter the amount:"))
            if amount<=self.__balance:  
                self.__balance -= amount
                print("Amout Withdrawed Successfully..")
            else:
                print("Insufficient funds..")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        temp = input("Enter Your Pin:")
        if temp == self.__pin:
            print("Your balance is {}".format(self.__balance))
            print("Balance Fetched Successfully..")
        else:
            print("Invalid Pin")

# %%
hdfc = Atm()

# %%
hdfc._Atm__pin ## that why it is called that 'Nothing in Python is truly private'

# %%
hdfc.get_pin()

# %% [markdown]
# ## Reference Varible
# - At the time of object creation in which varaible we saved the reference is called 'Reference Variable'.

# %%
a = 3

# %%
b = a

# %%
id(a)

# %%
id(b)

# %% [markdown]
# - Objects of the class are also mutable like list, dict and sets

# %%
class Customer():
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def intro(self):
        print("I am {} and I am {} years old.".format(self.name,self.age))

c1 = Customer('Yash',19)
c2 = Customer('Y',20)
c3 = Customer('M',18)

L = [c1,c2,c3]

for i in L:
    print(i.name,i.age)

# %%
class Atm:
    ## Constructor -> It is a special method that is outomatically executed when the instance of the class is created.
    def __init__(self):
        self.__pin = ""
        self.__balance = 0

        self.sno = 0

        ## we use double underscore __ before name of variable to make them private and can not be accessed 

        self.menu()

    def get_pin(self):
        return self.__pin

    def menu(self):
        user_input = input("""Hello, how would you like to proceed? 
                              1. Enter 1 to create pin
                              2. Enter 2 to deposit
                              3. Enter 3 to withdraw
                              4. Enter 4 to check balance
                              5. Enter 5 to exit
        """)

        if user_input == '1':
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        else:
            print("By by")

    def create_pin(self):
        p = input("Enter Your Pin")
        self.__pin = p
        print("Pin Set Successfully..")
        
    def deposit(self):
        temp = input("Enter Your Pin:")
        if temp == self.pin:
            amount = int(input("Enter the amount:"))
            self.__balance += amount
            print("Amout Deposited Successfully..")
        else:
            print("Invalid Pin")
            
    def withdraw(self):
        temp = input("Enter Your Pin:")
        if temp == self.__pin:
            amount = int(input("Enter the amount:"))
            if amount<=self.__balance:  
                self.__balance -= amount
                print("Amout Withdrawed Successfully..")
            else:
                print("Insufficient funds..")
        else:
            print("Invalid Pin")
            
    def check_balance(self):
        temp = input("Enter Your Pin:")
        if temp == self.__pin:
            print("Your balance is {}".format(self.__balance))
            print("Balance Fetched Successfully..")
        else:
            print("Invalid Pin")

# %% [markdown]
# ## Static/Class varaible
# - Variable whose value is same for every object is called static/class variable.

# %% [markdown]
# - Instance variable are define inside the constructor and static are defined outside the constructor.

# %%
class Atm:

    __counter = 1
    
    ## Constructor -> It is a special method that is outomatically executed when the instance of the class is created.
    def __init__(self):
        self.__pin = ""
        self.__balance = 0

        self.sno = Atm.__counter
        Atm.__counter = Atm.__counter + 1

        ## we use double underscore __ before name of variable to make them private and can not be accessed 

    ## Here we don't need self so this type of methods are called 'static methods'
    @staticmethod 
    def get_counter():
        return Atm.__counter

    @staticmethod
    def set_counter(new):
        if type(new) == int:
            Atm.__counter = new
        else:
            print("Not allowed..")
        
    def get_pin(self):
        return self.__pin

# %%
c1 = Atm()
c2 = Atm()
c3 = Atm()

# %%
c1.sno

# %%
c2.sno

# %%
c3.sno

# %%
c1.get_counter()

# %%
c2.get_counter()

# %%
c1.set_counter(5)

# %%
c2.get_counter()

# %%
c1.get_counter()

# %%
Atm.get_counter()

# %%
Atm.set_counter(6)

# %%
Atm.get_counter()

# %% [markdown]
# ## Relation between classes is of two types
# - Aggregation (Has-a relation)
# - Inheritance (Is-a relation)
#
# - Examples -->
# - > Car is a Vehicle
# - > Customer has a Address

# %%
class Customer():
    def __init__(self,name,gender,address):
        self.name = name
        self.gener = gender
        self.address = address

    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.change_address(new_city,new_pin,new_state)

class Address():
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode = pincode
        self.state = state

    def change_address(self,new_city,new_pin,new_state):
        self.city = new_city
        self.pincode = new_pin
        self.state = new_state

# %%
add = Address("Indore",452015,"MP")
cust = Customer("Yash","Male",add)

cust.edit_profile("YASH","Gurgaon",122011,"Haryana")

# %%
print(cust.address)

# %%
print(cust.address.city)
# Out:
# Gurgaon

# %% [markdown]
# ## Inheritance

# %% [markdown]
# - Biggest advantage of inheritance is code reusability.
# - Private members are not inherited.

# %%
class User:
    def login(self):
        print("Login")

    def register(self):
        print("Register")

class Student(User):
    def enroll(self):
        print("Enroll")
    def review(self):
        print("Review")


stu1 = Student()

stu1.enroll()
stu1.login()
stu1.register()
stu1.review()
# Out:
# Enroll
# Login
# Register
# Review

# %%
# u1 = User()

# u1.enroll()
# u1.login()
# u1.register()
# u1.review()

# ## But this will throw error because this is not possible

# %%
######### Inheriting Constructor 

class Phone:
    def __init__(self,price,brand,camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand 
        self.camera = camera

class SmartPhone(Phone):
    pass


s = SmartPhone(20000,'Apple',13)
# Out:
# Inside phone constructor

# %%
print(s.brand)
# Out:
# Apple

# %%
######### Inheriting Private Members
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.price = price
        self.__brand = brand
        self.camera = camera

class SmartPhone(Phone):
    pass


s = SmartPhone(20000,'Apple',13)
print(s.__brand) ## This line will throw error because it can no access private members
# Out:
# Inside Phone Constructor
# Apple

# %%
######### Method Overriding ##### (Concept of Polymorphism)
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.price = price
        self.__brand = brand
        self.camera = camera
    def buy(self):
        print("Buying a Phone..")

class SmartPhone(Phone):
    def buy(self):
        print("Buying a Smart Phone..")


s = SmartPhone(20000,'Apple',13)
s.buy() ## will call its own method not to the parent's same method..
# Out:
# Inside Phone Constructor
# Buying a Smart Phone..

# %%
class Parent:
    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):
    def show(self):
        print("This is in child class")

son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:
    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):
    def __init__(self,val,num):
        self.__val = val

    def get_val(self):
        return self.__val


son = Child(100,10)
print("Parent Num",son.get_num())
print("Child Val",son.get_val())

## this will raise error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8b88dae2a7bb> in <cell line: 18>()
#      16
#      17 son = Child(100,10)
# ---> 18 print("Parent Num",son.get_num())
#      19 print("Child Val",son.get_val())
#
# <ipython-input-2-8b88dae2a7bb> in get_num(self)
#       4
#       5     def get_num(self):
# ----> 6         return self.__num
#       7
#       8 class Child(Parent):
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %% [markdown]
# If child class has no constructor then constuctor of Parent class is called or used and if child class has constructor then its own is used/accessed.

# %%
class A:
    def __init__(self):
        self.var1 = 100

    def display1(self,var1):
        print("Class A:",self.var1)


class B(A):
    def display2(self,var1):
        print("Class B:",self.var1)

obj = B()
obj.display1(200)
# Out:
# Class A: 100

# %% [markdown]
# ## Use of Super()

# %%
class Phone():
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a phone")


class SmartPhone(Phone):
    def buy(self):
        print("Buying a smartphone")
        super().buy() ## It means accessing the buy() method of parent class

s = SmartPhone(20000,"Apple",13)
s.buy()
# Out:
# Inside Phone Constructor
# Buying a smartphone
# Buying a phone

# %%
######### Super Example 
class Phone():
    def __init__(self,price,brand,camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self,price,brand,camera,os,ram):
        print("Pehle Yahan..")
        super().__init__(price,brand,camera)
        self.os = os
        self.ram = ram
        print("Inside smartphone constructor")

s = SmartPhone(20000,"Samsung",12,"Android",2)

print(s.os)
print(s.brand)
# Out:
# Pehle Yahan..
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %%
############ Example of Super()

class Parent:
    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):
    def __init__(self,num,val):
        super().__init__(num)
        self.__val = val

    def get_val(self):
        return self.__val

son = Child(100,200)
print(son.get_num())
print(son.get_val)
# Out:
# 100
# <bound method Child.get_val of <__main__.Child object at 0x7808cd3302e0>>

# %%
class Parent:
    def __init__(self):
        self.num = 100

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.var = 200
    def show(self):
        print(self.num)
        print(self.var)

son = Child()
son.show()
# Out:
# 100
# 200

# %%
## Example
class Parent():
    def __init__(self):
        self.__num = 100
    def show(self):
        print("Parent",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var = 10

    def show(self):
        print("Child",self.__var)

dad = Parent()
dad.show()

son = Child()
son.show()
# Out:
# Parent 100
# Child 10

# %% [markdown]
# ## Types of Inheritance -->
# ### 1. Single Level
# ### 2. Multi Level
# ### 3. Hierarichal
# ### 4. Multiple (Not Possible in Java)
# ### 5. Hybrid (Combination of aboves)

# %%
##### Single Level
class Phone:
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a Phone")

    def return_phone(self):
        print("Returning a Phone")

class SmartPhone(Phone):
    pass

s = SmartPhone(1000,'Samsung',13)
s.buy()
# Out:
# Inside Phone Constructor
# Buying a Phone

# %%
######## Multi Level
class Product():
    def review(self):
        print("Product customer review")

class Phone(Product):
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a Phone")

    def return_phone(self):
        print("Returning a Phone")

class SmartPhone(Phone):
    pass

s = SmartPhone(1000,'Samsung',13)
p = Phone(2000,'Samsung',10)
s.buy()
s.review()
p.review()
# Out:
# Inside Phone Constructor
# Inside Phone Constructor
# Buying a Phone
# Product customer review
# Product customer review

# %%
##### Multiple 
class Phone(Product):
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a Phone")

    def return_phone(self):
        print("Returning a Phone")

class Product():
    def review(self):
        print("Customer review")

class SmartPhone(Phone,Product):
    pass

s = SmartPhone(1000,'Samsung',13)

s.buy()
s.review()
# Out:
# Inside Phone Constructor
# Buying a Phone
# Product customer review

# %%
### Classes have priorities in order

## and this concept is known as MRO(Method Resolution Order)
class Phone():
    def __init__(self,price,brand,camera):
        print("Inside Phone Constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Phone Buy Method")

class Product():
    def buy(self):
        print("Product Buy Method")

class SmartPhone(Phone,Product):
    pass

s = SmartPhone(1000,'Samsung',13)

s.buy()
# Out:
# Inside Phone Constructor
# Phone Buy Method

# %%
## Example of Multi Level Inheritance
class A:
    def m1(self):
        return 20

class B(A):
    def m1(self):
        return 30
    def m2(self):
        return 40

class C(B):
    def m2(self):
        return 20

obj1 = A()
obj2 = B()
obj3 = C()

print(obj1.m1(),obj3.m1(),obj3.m2())
# Out:
# 20 30 20

# %% [markdown]
# ## Method Overloading and Operator Overloading (Concepts of Polymorphism)

# %%
class Geometry:
    def area(self,a,b=0):
        if b==0:
            print("Circle",3.14*a**2)
        else:
            print("Rectangle",a*b)

## This is how we can implement method overloading in Python but it is not like JAVA's
            

    

obj = Geometry()

# %%
obj.area(30,40)
obj.area(40)
obj.area(20)
# Out:
# Rectangle 1200
# Circle 5024.0
# Circle 1256.0

# %%
### Operator Overloading --> We do operator overloading using magic methods for example we changed the behaviour of "+" in our 'Fraction' class

# %% [markdown]
# ## Let's Create a Project using train api
# from https://indianrailapi.com/api-collection

# %%
# http://indianrailapi.com/api/v2/TrainSchedule/apikey/<apikey>/TrainNumber/<TrainNumber>/

# %%
http://indianrailapi.com/api/v2/TrainSchedule/apikey/30c382602bfa67c8a7c580e6cfe2becb/TrainNumber/<TrainNumber>/
# 30c382602bfa67c8a7c580e6cfe2becb
